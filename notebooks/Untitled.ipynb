# %% [markdown]
# # Coston 2 custom-node (RPC only)

# %%
from pathlib import Path
import pandas as pd
import json

data_dir = Path("..") / "data" / "derived"

# %%
# Read the Parquet files 
df_blocks   = pd.read_parquet(data_dir / "df_blocks.parquet")
df_snowball = pd.read_parquet(data_dir / "df_snowball.parquet")

# %%
print(f"Parsed {len(df_blocks)} blocks from Coston 2.")
# Out:
# Parsed 212228 blocks from Coston 2.

# %%
from collections import Counter

slot_gt0 = df_blocks.query("slot > 0")

# remove self before counting
clean_prev = slot_gt0.apply(
    lambda r: [p for p in r.prevProposers if p != r.proposerID],
    axis=1
)

proposer_counts = clean_prev.explode().value_counts()

print("Rows where proposerID appeared in prevProposers:",
      (slot_gt0.apply(lambda r: r.proposerID in r.prevProposers, axis=1)).sum())

proposer_counter
# Out:
# Rows where proposerID appeared in prevProposers: 3800
# Counter({'NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1': 3882,
#          'NodeID-87skCc745aTkJEtozqTJ2SBnZ8Vb8Ncbd': 3306,
#          'NodeID-K6pAWivFKy38hCZSd4epCt7TW4fzXz7kP': 3253,
#          'NodeID-2mCUTA33bHU4vb8NQHE8QewftqC8p1fv8': 3208,
#          'NodeID-CZYx3on11wwYXFoHwZtAQZT5unZ9JHMf6': 3199,
#          'NodeID-AKt7WaK6ozEy5K8azKNacZXLzxZ9xFgC7': 3114,
#          'NodeID-ECqqsWu9jpUvZgPyf9yPZZcyWmJjWyN1T': 968})

# %%
# Snowball count per block heigh
snowball_per_height = (
    df_snowball.groupby("height").size()
)

df_blocks["snowball_blocks"] = (
    df_blocks["height"]
      .map(snowball_per_height)
      .fillna(0)
      .astype(int)
)

# %%
print(f"Parsed a total of {len(df_blocks)} blocks.")

slot0 = len(df_blocks[df_blocks['slot'] != 0])
print(f"Instances where block was NOT created in first slot: {slot0}")
      
multiple_snowballs = len(df_blocks[df_blocks["snowball_blocks"] > 1])
print(f"Instances where multiple blocks were proposed at same height: {multiple_snowballs}.")
# Out:
# Parsed a total of 212228 blocks.
# Instances where block was NOT created in first slot: 17706
# Instances where multiple blocks were proposed at same height: 28.

# %%
df_blocks[(df_blocks["snowball_blocks"] > 1) & (df_blocks['slot'] == 0)]
# this could only happen if the proposer actually proposed multiple in the initial slot
# TODO: add gas usage, # of txs for each proposed block
# per-block polls and consensus-metrics
# Out:
#                                                     blkID    height  \
# 7758    8YmHVLyfzfPY2UgaL5RZQjvv6U4JaDwrRXLLpxUbExozXmVqw  19881243
# 17000   SwLXLP8WR7nLEX1m6oaubbbbQaybe1r5wg3GHVjq8TMGsBPof  19890616
# 20564   EuDNVpc5gVBY2pRS1VfrHQzHLjao2cgFgLt3Egz53Tj5QZDXg  19894973
# 26979   2KNP2X4Evdeemgd4L11VtkQgmPkm2dXhsskxWG8qMW1Te7...  19900056
# 70199   E5j6j2i51F4ZanJVuXyhbdwsoeLfpqYae9WfXfTunaia1CDR3  19943408
# 91145   2kBomcs9LGg7uEm3AScoTr9vVazDV2KwN2gBe8ZSqT3fBU...  19964689
# 96541   BdF4VcvUqAGiLEBDWPDkRxXawwUHBFfzmUyAjVZe6kAgY8DPi  19969847
# 104207  tE6rBe1TzyriB7x6CnjDZXuu9Nkk1fjrruZQPi8kHWkcfRHd1  19977929
# 105282  JmwYF6pkGorVK6yktgyqRB4JZ18bTZNPF28GsuDrN22qrvoGy  19979510
# 113192  2mtt6jMHR4sLuU5hTou3PdoAzdDMjJVcgeJzF6yK3jtiYG...  19987353
# 120766  2JZPtxbFxCVQBzuVVxn8g7LEFpEBxjVbtGq51bhGEWpjZu...  19995528
# 129352  7492iriusNvceGg2XsmPmEHgL9FwsP5jmFBZkccnyDQgsgPdv  20003149
# 135664  2oX7Ni8g9qpEZkd7qRVb8NVdAg6DyJjf9PjRQR6nCuRBXS...  20010194
# 168526  2671r4JWJvNMTBWi2xajv6S5RLmdyBKzoaCmDuLpHEP6c4...  20043158
# 175597  ZVfey91tv42QcHMdf57y15SRGAE8iLHhyx1XukcMm5CTXtibe  20048861
# 179016  h31Qx9TW8qs54xMrMCrBSDbpdcpnRaUG4Zj9CoqVzzswRwE4r  20054151
# 187823  2JNTcVJ5fUhoEcg85qEoA1yQ7qAGJkpdXeBJXGPWDY8jj7...  20062212
# 197242  AEargqw5hND5eg5iGcfZEPup5KWi9wYf9KqAtfRj1Jek5opNM  20071453
# 201215  s9AwPAwKTYGAAYvc1TN4w5g1SS5hLUaRsr8ovbyGaK2FMpTtr  20075347
#
#         pChainHeight                                proposerID  slot  \
# 7758            9911  NodeID-87skCc745aTkJEtozqTJ2SBnZ8Vb8Ncbd     0
# 17000           9916  NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1     0
# 20564           9916  NodeID-CZYx3on11wwYXFoHwZtAQZT5unZ9JHMf6     0
# 26979           9916  NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1     0
# 70199           9925  NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1     0
# 91145           9925  NodeID-87skCc745aTkJEtozqTJ2SBnZ8Vb8Ncbd     0
# 96541           9925  NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1     0
# 104207          9925  NodeID-CZYx3on11wwYXFoHwZtAQZT5unZ9JHMf6     0
# 105282          9925  NodeID-87skCc745aTkJEtozqTJ2SBnZ8Vb8Ncbd     0
# 113192          9925  NodeID-AKt7WaK6ozEy5K8azKNacZXLzxZ9xFgC7     0
# 120766          9925  NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1     0
# 129352          9925  NodeID-2mCUTA33bHU4vb8NQHE8QewftqC8p1fv8     0
# 135664          9925  NodeID-AKt7WaK6ozEy5K8azKNacZXLzxZ9xFgC7     0
# 168526          9928  NodeID-87skCc745aTkJEtozqTJ2SBnZ8Vb8Ncbd     0
# 175597          9928  NodeID-K6pAWivFKy38hCZSd4epCt7TW4fzXz7kP     0
# 179016          9928  NodeID-87skCc745aTkJEtozqTJ2SBnZ8Vb8Ncbd     0
# 187823          9928  NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1     0
# 197242          9928  NodeID-FQKTLuZHEsjCxPeFTFgsojsucmdyNDsz1     0
# 201215          9928  NodeID-AKt7WaK6ozEy5K8azKNacZXLzxZ9xFgC7     0
#
#         firstSlot prevProposers  snowball_blocks
# 7758         True            []                2
# 17000        True            []                2
# 20564        True            []                2
# 26979        True            []                2
# 70199        True            []                2
# 91145        True            []                2
# 96541        True            []                2
# 104207       True            []                2
# 105282       True            []                2
# 113192       True            []                2
# 120766       True            []                2
# 129352       True            []                2
# 135664       True            []                2
# 168526       True            []                2
# 175597       True            []                2
# 179016       True            []                2
# 187823       True            []                2
# 197242       True            []                2
# 201215       True            []                2

# %%
df_blocks[df_blocks['height'] == 19881243+1]
# Out:
#                                                   blkID    height  \
# 7757  2hYSoVy8wzmTivzxf3Gu6SH8eC2a95Bkf73Ew5kbU1tRNV...  19881244
#
#       pChainHeight                                proposerID  slot  firstSlot  \
# 7757          9911  NodeID-CZYx3on11wwYXFoHwZtAQZT5unZ9JHMf6     0       True
#
#      prevProposers  snowball_blocks
# 7757            []                1

# %%
df_snowball[df_snowball['height'] == 19881243]
# Out:
#                                                   blkID    height
# 4722  8YmHVLyfzfPY2UgaL5RZQjvv6U4JaDwrRXLLpxUbExozXmVqw  19881243
# 4723  2q7F9QvGZqRtZmoKpPdwWwkLaSVpiXcgn6THJcdBW8F5rT...  19881243

# %%
(4.271892e+06 - (20*213553)) / 28
# Out:
# 29.714285714285715

# %%
#!/usr/bin/env python3
"""
Convert between Avalanche NodeID and Ethereum-style addresses.

Requirements (install in your own environment):
    pip install base58 ecdsa eth_utils

Usage:
    python convert_nodeid.py --nodeid NodeID-...      # get Ethereum address
    python convert_nodeid.py --privkey <hex>          # get NodeID from private key
"""

import argparse
import base58
from eth_utils import keccak, to_checksum_address
from ecdsa import VerifyingKey, SECP256k1, SigningKey

def nodeid_to_eth_address(node_id: str) -> str:
    """
    Convert an Avalanche NodeID (Base58Check) to an Ethereum-style address.
    """
    # Strip "NodeID-" prefix and Base58 decode with checksum
    b58 = node_id.split('-', 1)[1]
    decoded = base58.b58decode_check(b58)
    
    # Remove the network ID byte to get the compressed pubkey
    compressed_pk = decoded[1:]
    
    # Decompress the public key
    vk = VerifyingKey.from_string(compressed_pk, curve=SECP256k1)
    uncompressed_pk = b'\x04' + vk.to_string()
    
    # Ethereum address is last 20 bytes of keccak256(pubkey[1:])
    eth_address = to_checksum_address(keccak(uncompressed_pk[1:])[-20:])
    return eth_address

def privkey_to_nodeid(privkey_hex: str, network_id: int = 1) -> str:
    """
    Given a hex private key, derive and return the Avalanche NodeID.
    """
    sk = SigningKey.from_string(bytes.fromhex(privkey_hex), curve=SECP256k1)
    vk = sk.get_verifying_key()
    # Compress pubkey
    x = vk.pubkey.point.x()
    y = vk.pubkey.point.y()
    prefix = b'\x02' if y % 2 == 0 else b'\x03'
    compressed_pk = prefix + x.to_bytes(32, 'big')
    
    # Prefix network ID and Base58Check encode
    to_encode = bytes([network_id]) + compressed_pk
    nodeid_b58 = base58.b58encode_check(to_encode).decode()
    return f"NodeID-{nodeid_b58}"

# %%
eth = nodeid_to_eth_address("NodeID-BkJnMrPihNduN2iDBAtF9Esr5ednzF7FF")
print("Ethereum address:", eth)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 eth = nodeid_to_eth_address("NodeID-BkJnMrPihNduN2iDBAtF9Esr5ednzF7FF")
#       2 print("Ethereum address:", eth)
#
# Cell In[2], line 24, in nodeid_to_eth_address(node_id)
#      22 # Strip "NodeID-" prefix and Base58 decode with checksum
#      23 b58 = node_id.split('-', 1)[1]
# ---> 24 decoded = base58.b58decode_check(b58)
#      26 # Remove the network ID byte to get the compressed pubkey
#      27 compressed_pk = decoded[1:]
#
# File ~/Documents/Repos/github-flare-research/block-explorer/.venv/lib/python3.10/site-packages/base58/__init__.py:157, in b58decode_check(v, alphabet, autofix)
#     154 digest = sha256(sha256(result).digest()).digest()
#     156 if check != digest[:4]:
# --> 157     raise ValueError("Invalid checksum")
#     159 return result
#
# ValueError: Invalid checksum

# %%
nid = privkey_to_nodeid(args.privkey)
print("Avalanche NodeID:", nid)
